# %% [markdown]
# <a href="https://colab.research.google.com/github/KishoreKumar477/ml-regression/blob/main/titanicds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
# You may need to re-run this cell after logging in.
kagglehub.login()
path = kagglehub.competition_download('titanic')

# %%
import pandas as pd
import os
import seaborn as sns

for file in os.listdir(path):
    print("Files in dataset:", file)

# Load the dataset (usually filename is 'heart.csv' or similar)
df = pd.read_csv(os.path.join(path, "train.csv")) # Changed 'tested.csv' to 'train.csv'

df.head(1)
# Out:
# Files in dataset: gender_submission.csv
# Files in dataset: test.csv
# Files in dataset: train.csv
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df=df.drop(['Name','Ticket','Cabin'],axis=1)

# %%
df["Fare"]
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
df.loc[df["Fare"].isna(),"Fare"]=df["Fare"].median()

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df['Sex']=df["Sex"].map({"male":0,"female":1})

# %%
df['Embarked']=df["Embarked"].map({"S":0,"C":1,"Q":2})

# %%
df["Survived"] .sum()
# Out:
# np.int64(342)

# %%
x=df.drop("Survived",axis=1)
y=df["Survived"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,recall_score,precision_score

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
    )

# %%
model = LogisticRegression(max_iter=1000)
# Fill NaN values in 'Embarked' with the mode before training
x['Embarked'] = x['Embarked'].fillna(x['Embarked'].mode()[0])

# Re-split the data after imputation
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
    )

model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7988826815642458
